# %%
# %matplotlib inline
import os , sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

cur_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(cur_dir))
packages = 'Packages'
package = os.path.join(root_dir, packages)

# Adding Packages path 
sys.path.append(package)

from Nse_Helpers import Nse_Helpers

# %%
df = Nse_Helpers(stock_id='sbin', start_date='01-Jan-2018', end_date='10-Dec-2018').stock_dataset_between_days
df.head()
# Out:
# 2018-12-20 10:38:26,707 INFO stock_dataset_between_days --> Getting Stock price Dataset for stock=sbin for period
#            Symbol Series  Prev Close   Open    High     Low    Last   Close  \
# Date
# 2018-01-01   SBIN     EQ      309.90  310.6  312.75  306.30  306.75  307.10
# 2018-01-02   SBIN     EQ      307.10  309.0  309.00  301.35  303.00  303.25
# 2018-01-03   SBIN     EQ      303.25  305.3  306.45  302.15  302.80  302.85
# 2018-01-04   SBIN     EQ      302.85  304.5  310.20  303.15  309.25  308.50
# 2018-01-05   SBIN     EQ      308.50  311.4  311.40  305.60  307.25  306.35
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2018-01-01  309.08  12182400  3.765315e+14   75769             5697288
# 2018-01-02  304.00  14797364  4.498328e+14  100195             5698196
# 2018-01-03  304.32  13857373  4.217070e+14  117207             6941140
# 2018-01-04  307.63  24517099  7.542211e+14  140513            10508054
# ...

# %%
df.index
# Out:
# Index([2018-01-01, 2018-01-02, 2018-01-03, 2018-01-04, 2018-01-05, 2018-01-08,
#        2018-01-09, 2018-01-10],
#       dtype='object', name='Date')

# %% [markdown]
# ### For Time series problem using pandas its better to have the index in DatatimeIndex datatype
#     - Its is done so to ease data manipulation based on time

# %%
df.index = df.index.astype('datetime64[ns]')
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-08', '2018-01-09', '2018-01-10',
#                '2018-01-11', '2018-01-12',
#                ...
#                '2018-11-27', '2018-11-28', '2018-11-29', '2018-11-30',
#                '2018-12-03', '2018-12-04', '2018-12-05', '2018-12-06',
#                '2018-12-07', '2018-12-10'],
#               dtype='datetime64[ns]', name='Date', length=232, freq=None)

# %% [markdown]
# # Sample Plot of Data

# %%
df.plot(x=df.index, y='Close', figsize=(10, 6), title='{} Stock price Movement'.format(df.Symbol[0]), )

# %% [markdown]
# # Data manipulation example using time
# [Git_Tutorial](https://github.com/codebasics/py/blob/master/pandas/16_ts_holidays/pandas_ts_holidays_custombusinessday.ipynb
# )

# %% [markdown]
# ### show only jan data

# %%
df['2018-02']
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2018-02-01   SBIN     EQ      313.25  316.90  317.40  305.00  305.40  306.05
# 2018-02-02   SBIN     EQ      306.05  302.90  305.75  295.50  295.80  297.35
# 2018-02-05   SBIN     EQ      297.35  292.65  300.40  290.00  299.00  298.05
# 2018-02-06   SBIN     EQ      298.05  285.00  297.30  282.90  294.60  291.75
# 2018-02-07   SBIN     EQ      291.75  296.60  297.90  290.00  292.10  292.80
# 2018-02-08   SBIN     EQ      292.80  292.90  303.30  292.55  302.25  301.40
# 2018-02-09   SBIN     EQ      301.40  297.00  300.60  295.00  295.40  296.40
# 2018-02-12   SBIN     EQ      296.40  288.25  292.40  285.15  290.10  288.75
# 2018-02-14   SBIN     EQ      288.75  288.70  288.70  275.00  275.50  276.20
# 2018-02-15   SBIN     EQ      276.20  274.80  282.30  274.25  279.10  278.70
# 2018-02-16   SBIN     EQ      278.70  280.50  281.20  270.05  271.40  271.65
# ...

# %% [markdown]
# ### show date range data

# %%
df['2018-01':'2018-02-15']
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2018-01-01   SBIN     EQ      309.90  310.60  312.75  306.30  306.75  307.10
# 2018-01-02   SBIN     EQ      307.10  309.00  309.00  301.35  303.00  303.25
# 2018-01-03   SBIN     EQ      303.25  305.30  306.45  302.15  302.80  302.85
# 2018-01-04   SBIN     EQ      302.85  304.50  310.20  303.15  309.25  308.50
# 2018-01-05   SBIN     EQ      308.50  311.40  311.40  305.60  307.25  306.35
# 2018-01-08   SBIN     EQ      306.35  307.20  309.50  305.00  306.05  305.80
# 2018-01-09   SBIN     EQ      305.80  307.50  309.50  303.30  303.90  304.30
# 2018-01-10   SBIN     EQ      304.30  304.65  305.85  300.00  301.05  301.10
# 2018-01-11   SBIN     EQ      301.10  300.90  303.00  300.00  302.15  302.20
# 2018-01-12   SBIN     EQ      302.20  304.65  304.65  300.55  302.50  302.25
# 2018-01-15   SBIN     EQ      302.25  303.95  305.25  301.55  302.40  302.60
# ...

# %% [markdown]
# ## Resampling

# %%
df.Close.resample('W').mean().plot()

# %% [markdown]
# ## Creating Date Range with various frequency
#     - can create dates based on weekday, weekends, holidays, business days, etc

# %%
pd.date_range(start='1/Jan/2018', end='1/Feb/2018',freq='W')
# Out:
# DatetimeIndex(['2018-01-07', '2018-01-14', '2018-01-21', '2018-01-28'], dtype='datetime64[ns]', freq='W-SUN')

# %% [markdown]
# ### Custom Hoildays
#     - setting freq = 'B' consider only weekends as holidays, in case u need to include national holidays in it

# %%
from pandas.tseries import holiday

# %%
pd.period_range(start='1/Jan/2018', end='1/Feb/2019',freq='Q')
# Out:
# PeriodIndex(['2018Q1', '2018Q2', '2018Q3', '2018Q4', '2019Q1'], dtype='period[Q-DEC]', freq='Q-DEC')

# %% [markdown]
# [Reference_Link](https://towardsdatascience.com/an-end-to-end-project-on-time-series-analysis-and-forecasting-with-python-4835e6bf050b)
#
#
# [Link2](https://www.analyticsvidhya.com/blog/2018/02/time-series-forecasting-methods/)
#
#
# [Link3](https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/)
